# %% [markdown]
# <a href="https://colab.research.google.com/github/1steve78/1steve78/blob/main/InstantID_IPAdapter_ControlNet_FaceDetailer_jupyter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content
# !git clone -b totoro https://github.com/camenduru/ComfyUI /content/TotoroUI
# !git clone -b totoro_v2 https://github.com/camenduru/ComfyUI_IPAdapter_plus /content/TotoroUI/IPAdapter
# !git clone -b totoro https://github.com/camenduru/ComfyUI_InstantID /content/TotoroUI/InstantID
# !git clone -b totoro https://github.com/camenduru/ComfyUI-Impact-Pack /content/TotoroUI/Impact

# !pip install -q torch==2.2.1+cu121 torchvision==0.17.1+cu121 torchaudio==2.2.1+cu121 torchtext==0.17.1 torchdata==0.7.1 --extra-index-url https://download.pytorch.org/whl/cu121
# !pip install -q torchsde einops diffusers accelerate xformers==0.0.25 insightface onnxruntime onnxruntime-gpu ultralytics==8.2.27 segment-anything piexif
# !apt -y install -qq aria2

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/354657 -d /content/TotoroUI/models -o dreamshaperXL_lightningDPMSDE.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/470847 -d /content/TotoroUI/models -o raemuXL_v35Lightning.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/h94/IP-Adapter/resolve/main/models/image_encoder/model.safetensors -d /content/TotoroUI/models/clip_vision -o CLIP-ViT-H-14-laion2B-s32B-b79K.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/h94/IP-Adapter/resolve/main/sdxl_models/ip-adapter-plus-face_sdxl_vit-h.safetensors  -d /content/TotoroUI/models/ipadapter -o ip-adapter-plus-face_sdxl_vit-h.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lllyasviel/sd_control_collection/resolve/main/thibaud_xl_openpose.safetensors -d /content/TotoroUI/models/controlnet -o thibaud_xl_openpose.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://github.com/Ttl/ComfyUi_NNLatentUpscale/raw/master/sdxl_resizer.pt -d /content/TotoroUI/models -o sdxl_resizer.pt
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/DIAMONIK7777/antelopev2/resolve/main/1k3d68.onnx -d /content/TotoroUI/models/insightface/models/antelopev2 -o 1k3d68.onnx
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/DIAMONIK7777/antelopev2/resolve/main/2d106det.onnx -d /content/TotoroUI/models/insightface/models/antelopev2 -o 2d106det.onnx
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/DIAMONIK7777/antelopev2/resolve/main/genderage.onnx -d /content/TotoroUI/models/insightface/models/antelopev2 -o genderage.onnx
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/DIAMONIK7777/antelopev2/resolve/main/glintr100.onnx -d /content/TotoroUI/models/insightface/models/antelopev2 -o glintr100.onnx
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/DIAMONIK7777/antelopev2/resolve/main/scrfd_10g_bnkps.onnx -d /content/TotoroUI/models/insightface/models/antelopev2 -o scrfd_10g_bnkps.onnx
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/InstantX/InstantID/resolve/main/ip-adapter.bin -d /content/TotoroUI/models/instantid -o ip-adapter.bin
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/InstantX/InstantID/resolve/main/ControlNetModel/diffusion_pytorch_model.safetensors -d /content/TotoroUI/models/controlnet/SDXL/instantid -o diffusion_pytorch_model.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/IICF/resolve/main/ultralytics/bbox/Eyes.pt -d /content/TotoroUI/models/ultralytics/bbox -o Eyes.pt

# !wget https://huggingface.co/camenduru/IICF/resolve/main/test/anya.jpg -O /content/anya.jpg
# !wget https://huggingface.co/camenduru/IICF/resolve/main/test/pose_images.zip -O /content/pose_images.zip
# !unzip /content/pose_images.zip -d /content
# Out:
# /content
# Cloning into '/content/TotoroUI'...
# remote: Enumerating objects: 20484, done.
# remote: Total 20484 (delta 0), reused 0 (delta 0), pack-reused 20484 (from 1)
# Receiving objects: 100% (20484/20484), 65.43 MiB | 17.10 MiB/s, done.
# Resolving deltas: 100% (13661/13661), done.
# Cloning into '/content/TotoroUI/IPAdapter'...
# remote: Enumerating objects: 733, done.
# remote: Counting objects: 100% (376/376), done.
# remote: Compressing objects: 100% (106/106), done.
# remote: Total 733 (delta 357), reused 270 (delta 270), pack-reused 357 (from 1)
# Receiving objects: 100% (733/733), 4.71 MiB | 19.39 MiB/s, done.
# Resolving deltas: 100% (491/491), done.
# Cloning into '/content/TotoroUI/InstantID'...
# remote: Enumerating objects: 160, done.
# remote: Counting objects: 100% (73/73), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 160 (delta 68), reused 60 (delta 60), pack-reused 87 (from 1)
# Receiving objects: 100% (160/160), 1.61 MiB | 22.23 MiB/s, done.
# Resolving deltas: 100% (95/95), done.
# Cloning into '/content/TotoroUI/Impact'...
# remote: Enumerating objects: 4234, done.
# remote: Total 4234 (delta 0), reused 0 (delta 0), pack-reused 4234 (from 1)
# Receiving objects: 100% (4234/4234), 31.70 MiB | 13.89 MiB/s, done.
# Resolving deltas: 100% (2825/2825), done.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 757.2/757.2 MB 1.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 138.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 125.7 MB/s eta 0:00:00
# ERROR: Could not find a version that satisfies the requirement torchtext==0.17.1 (from versions: 0.1.1, 0.2.0, 0.2.1, 0.2.3, 0.3.1, 0.4.0, 0.5.0, 0.6.0, 0.16.2, 0.16.2+cpu, 0.17.2, 0.18.0)
# ERROR: No matching distribution found for torchtext==0.17.1
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 116.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 439.5/439.5 kB 43.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.2/41.2 kB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 779.6/779.6 kB 57.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 7.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 102.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 252.6/252.6 MB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.5/17.5 MB 85.7 MB/s eta 0:00:00
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Building wheel for xformers (setup.py) ... error
#   ERROR: Failed building wheel for xformers
#   Building wheel for insightface (pyproject.toml) ... done
# ERROR: ERROR: Failed to build installable wheels for some pyproject.toml based projects (xformers)
# The following additional packages will be installed:
#   libaria2-0 libc-ares2
# The following NEW packages will be installed:
#   aria2 libaria2-0 libc-ares2
# 0 upgraded, 3 newly installed, 0 to remove and 37 not upgraded.
# Need to get 1,513 kB of archives.
# After this operation, 5,441 kB of additional disk space will be used.
# Selecting previously unselected package libc-ares2:amd64.
# (Reading database ... 121852 files and directories currently installed.)
# Preparing to unpack .../libc-ares2_1.18.1-1ubuntu0.22.04.3_amd64.deb ...
# Unpacking libc-ares2:amd64 (1.18.1-1ubuntu0.22.04.3) ...
# Selecting previously unselected package libaria2-0:amd64.
# Preparing to unpack .../libaria2-0_1.36.0-1_amd64.deb ...
# Unpacking libaria2-0:amd64 (1.36.0-1) ...
# Selecting previously unselected package aria2.
# Preparing to unpack .../aria2_1.36.0-1_amd64.deb ...
# Unpacking aria2 (1.36.0-1) ...
# Setting up libc-ares2:amd64 (1.18.1-1ubuntu0.22.04.3) ...
# Setting up libaria2-0:amd64 (1.36.0-1) ...
# Setting up aria2 (1.36.0-1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# dda930|OK  |   149MiB/s|/content/TotoroUI/models/dreamshaperXL_lightningDPMSDE.safetensors
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 04d0c7|OK  |   153MiB/s|/content/TotoroUI/models/clip_vision/CLIP-ViT-H-14-laion2B-s32B-b79K.safetensors
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# d69975|OK  |   131MiB/s|/content/TotoroUI/models/ipadapter/ip-adapter-plus-face_sdxl_vit-h.safetensors
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 76c673|OK  |   175MiB/s|/content/TotoroUI/models/controlnet/thibaud_xl_openpose.safetensors
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 745138|OK  |   114MiB/s|/content/TotoroUI/models/sdxl_resizer.pt
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# e7b139|OK  |    55MiB/s|/content/TotoroUI/models/insightface/models/antelopev2/1k3d68.onnx
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 59f973|OK  |   8.7MiB/s|/content/TotoroUI/models/insightface/models/antelopev2/2d106det.onnx
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 951380|OK  |   2.0MiB/s|/content/TotoroUI/models/insightface/models/antelopev2/genderage.onnx
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 0c1f40|OK  |   119MiB/s|/content/TotoroUI/models/insightface/models/antelopev2/glintr100.onnx
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 91e258|OK  |    21MiB/s|/content/TotoroUI/models/insightface/models/antelopev2/scrfd_10g_bnkps.onnx
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 60b28b|OK  |   128MiB/s|/content/TotoroUI/models/instantid/ip-adapter.bin
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 451cd9|OK  |   136MiB/s|/content/TotoroUI/models/controlnet/SDXL/instantid/diffusion_pytorch_model.safetensors
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 5388ae|OK  |   2.8MiB/s|/content/TotoroUI/models/ultralytics/bbox/Eyes.pt
#
# Status Legend:
# (OK):download completed.
# --2026-03-03 08:02:55--  https://huggingface.co/camenduru/IICF/resolve/main/test/anya.jpg
# Resolving huggingface.co (huggingface.co)... 13.35.202.97, 13.35.202.34, 13.35.202.121, ...
# Connecting to huggingface.co (huggingface.co)|13.35.202.97|:443... connected.
# HTTP request sent, awaiting response... 307 Temporary Redirect
# Location: /api/resolve-cache/models/camenduru/IICF/54e0d03579ecbe437b97f8c8b743b2963e6b36bf/test%2Fanya.jpg?%2Fcamenduru%2FIICF%2Fresolve%2Fmain%2Ftest%2Fanya.jpg=&etag=%22e1d673f0f6136e970943bf3dec06136b0ed60cde%22 [following]
# --2026-03-03 08:02:55--  https://huggingface.co/api/resolve-cache/models/camenduru/IICF/54e0d03579ecbe437b97f8c8b743b2963e6b36bf/test%2Fanya.jpg?%2Fcamenduru%2FIICF%2Fresolve%2Fmain%2Ftest%2Fanya.jpg=&etag=%22e1d673f0f6136e970943bf3dec06136b0ed60cde%22
# Reusing existing connection to huggingface.co:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 78694 (77K) [image/jpeg]
# Saving to: ‘/content/anya.jpg’
#
# /content/anya.jpg   100%[===================>]  76.85K  --.-KB/s    in 0.002s
#
# 2026-03-03 08:02:55 (41.0 MB/s) - ‘/content/anya.jpg’ saved [78694/78694]
#
# --2026-03-03 08:02:56--  https://huggingface.co/camenduru/IICF/resolve/main/test/pose_images.zip
# Resolving huggingface.co (huggingface.co)... 13.35.202.34, 13.35.202.40, 13.35.202.121, ...
# Connecting to huggingface.co (huggingface.co)|13.35.202.34|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://us.gcp.cdn.hf.co/xet-bridge-us/665d290c2080b38e5d528e79/ebc60237cb84d3279077b080058abcb1e703e6d75a37d1cbae8246e709af6998?response-content-disposition=inline%3B+filename*%3DUTF-8%27%27pose_images.zip%3B+filename%3D%22pose_images.zip%22%3B&response-content-type=application%2Fzip&Expires=1772528576&Policy=&Signature=XtyarP8W6LUt5C9nD5%7E8iIK4Bkbh2qqn-NCk13X00w%7EdfZyE4KcvriMXfUbvjs%7EqrYga%7EZdTdt6onPgrap7BR6diUYAGUGdASuQL51pK0ltdA8LgEjnfukeIx2Mqd3pMVW7bXQjrhUjBVKFEnv4GTntIMklJD9rceDNftt12YI-vGCvBxe4y8Dr40sR0NvjQpBcpMQ4K8t7rtkcL4DhB0BLu-63SH7x5dZ-70SUT6jvxoXykvcR98P161Gpt808%7ESlMWOT4Nl%7ENHh-FGSijgcbmfOj07KKkyg3Eb2NfUncN7WKjMPwIuYCixEj%7Ea6MNo1L6bBpOJD0yYBAA1z8Jyxw__&Key-Pair-Id=KJLH8B0YWU4Y8M [following]
# --2026-03-03 08:02:56--  https://us.gcp.cdn.hf.co/xet-bridge-us/665d290c2080b38e5d528e79/ebc60237cb84d3279077b080058abcb1e703e6d75a37d1cbae8246e709af6998?response-content-disposition=inline%3B+filename*%3DUTF-8%27%27pose_images.zip%3B+filename%3D%22pose_images.zip%22%3B&response-content-type=application%2Fzip&Expires=1772528576&Policy=&Signature=XtyarP8W6LUt5C9nD5%7E8iIK4Bkbh2qqn-NCk13X00w%7EdfZyE4KcvriMXfUbvjs%7EqrYga%7EZdTdt6onPgrap7BR6diUYAGUGdASuQL51pK0ltdA8LgEjnfukeIx2Mqd3pMVW7bXQjrhUjBVKFEnv4GTntIMklJD9rceDNftt12YI-vGCvBxe4y8Dr40sR0NvjQpBcpMQ4K8t7rtkcL4DhB0BLu-63SH7x5dZ-70SUT6jvxoXykvcR98P161Gpt808%7ESlMWOT4Nl%7ENHh-FGSijgcbmfOj07KKkyg3Eb2NfUncN7WKjMPwIuYCixEj%7Ea6MNo1L6bBpOJD0yYBAA1z8Jyxw__&Key-Pair-Id=KJLH8B0YWU4Y8M
# Resolving us.gcp.cdn.hf.co (us.gcp.cdn.hf.co)... 35.213.163.44
# Connecting to us.gcp.cdn.hf.co (us.gcp.cdn.hf.co)|35.213.163.44|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2585058 (2.5M) [application/zip]
# Saving to: ‘/content/pose_images.zip’
#
# /content/pose_image 100%[===================>]   2.46M  3.29MB/s    in 0.7s
#
# 2026-03-03 08:02:57 (3.29 MB/s) - ‘/content/pose_images.zip’ saved [2585058/2585058]
#
# Archive:  /content/pose_images.zip
#    creating: /content/pose_images/
#   inflating: /content/pose_images/headshot_dw_pose_00001_.png
#   inflating: /content/pose_images/headshot_dw_pose_00002_.png
#   inflating: /content/pose_images/headshot_dw_pose_00003_.png
#   inflating: /content/pose_images/headshot_dw_pose_00004_.png
#   inflating: /content/pose_images/headshot_dw_pose_00005_.png
#   inflating: /content/pose_images/headshot_dw_pose_00006_.png
#   inflating: /content/pose_images/headshot_dw_pose_00007_.png
#   inflating: /content/pose_images/headshot_dw_pose_00008_.png
#   inflating: /content/pose_images/headshot_dw_pose_00009_.png
#   inflating: /content/pose_images/headshot_dw_pose_00010_.png
#   inflating: /content/pose_images/headshot_dw_pose_00011_.png
#   inflating: /content/pose_images/headshot_dw_pose_00012_.png
#   inflating: /content/pose_images/headshot_dw_pose_00013_.png
#   inflating: /content/pose_images/headshot_dw_pose_00014_.png
#   inflating: /content/pose_images/headshot_kps_00001_.png
#   inflating: /content/pose_images/headshot_kps_00002_.png
#   inflating: /content/pose_images/headshot_kps_00003_.png
#   inflating: /content/pose_images/headshot_kps_00004_.png
#   inflating: /content/pose_images/headshot_kps_00005_.png
#   inflating: /content/pose_images/headshot_kps_00006_.png
#   inflating: /content/pose_images/headshot_kps_00007_.png
#   inflating: /content/pose_images/headshot_kps_00008_.png
#   inflating: /content/pose_images/headshot_kps_00009_.png
#   inflating: /content/pose_images/headshot_kps_00010_.png
#   inflating: /content/pose_images/headshot_kps_00011_.png
#   inflating: /content/pose_images/headshot_kps_00012_.png
#   inflating: /content/pose_images/headshot_kps_00013_.png
#   inflating: /content/pose_images/headshot_kps_00014_.png
#   inflating: /content/pose_images/headshot_open_pose_00001_.png
#   inflating: /content/pose_images/headshot_open_pose_00002_.png
#   inflating: /content/pose_images/headshot_open_pose_00003_.png
#   inflating: /content/pose_images/headshot_open_pose_00004_.png
#   inflating: /content/pose_images/headshot_open_pose_00005_.png
#   inflating: /content/pose_images/headshot_open_pose_00006_.png
#   inflating: /content/pose_images/headshot_open_pose_00007_.png
#   inflating: /content/pose_images/headshot_open_pose_00008_.png
#   inflating: /content/pose_images/headshot_open_pose_00009_.png
#   inflating: /content/pose_images/headshot_open_pose_00010_.png
#   inflating: /content/pose_images/headshot_open_pose_00011_.png
#   inflating: /content/pose_images/headshot_open_pose_00012_.png
#   inflating: /content/pose_images/headshot_open_pose_00013_.png
#   inflating: /content/pose_images/headshot_open_pose_00014_.png
#   inflating: /content/pose_images/pose_dw_pose_00001_.png
#   inflating: /content/pose_images/pose_dw_pose_00002_.png
#   inflating: /content/pose_images/pose_dw_pose_00003_.png
#   inflating: /content/pose_images/pose_dw_pose_00004_.png
#   inflating: /content/pose_images/pose_dw_pose_00005_.png
#   inflating: /content/pose_images/pose_dw_pose_00006_.png
#   inflating: /content/pose_images/pose_dw_pose_00007_.png
#   inflating: /content/pose_images/pose_dw_pose_00008_.png
#   inflating: /content/pose_images/pose_dw_pose_00009_.png
#   inflating: /content/pose_images/pose_dw_pose_00010_.png
#   inflating: /content/pose_images/pose_dw_pose_00011_.png
#   inflating: /content/pose_images/pose_dw_pose_00012_.png
#   inflating: /content/pose_images/pose_dw_pose_00013_.png
#   inflating: /content/pose_images/pose_dw_pose_00014_.png
#   inflating: /content/pose_images/pose_dw_pose_00015_.png
#   inflating: /content/pose_images/pose_dw_pose_00016_.png
#   inflating: /content/pose_images/pose_dw_pose_00017_.png
#   inflating: /content/pose_images/pose_dw_pose_00018_.png
#   inflating: /content/pose_images/pose_dw_pose_00019_.png
#   inflating: /content/pose_images/pose_dw_pose_00020_.png
#   inflating: /content/pose_images/pose_dw_pose_00021_.png
#   inflating: /content/pose_images/pose_dw_pose_00022_.png
#   inflating: /content/pose_images/pose_dw_pose_00023_.png
#   inflating: /content/pose_images/pose_dw_pose_00024_.png
#   inflating: /content/pose_images/pose_dw_pose_00025_.png
#   inflating: /content/pose_images/pose_dw_pose_00026_.png
#   inflating: /content/pose_images/pose_dw_pose_00027_.png
#   inflating: /content/pose_images/pose_dw_pose_00028_.png
#   inflating: /content/pose_images/pose_dw_pose_00029_.png
#   inflating: /content/pose_images/pose_dw_pose_00030_.png
#   inflating: /content/pose_images/pose_kps_00001_.png
#   inflating: /content/pose_images/pose_kps_00002_.png
#   inflating: /content/pose_images/pose_kps_00003_.png
#   inflating: /content/pose_images/pose_kps_00004_.png
#   inflating: /content/pose_images/pose_kps_00005_.png
#   inflating: /content/pose_images/pose_kps_00006_.png
#   inflating: /content/pose_images/pose_kps_00007_.png
#   inflating: /content/pose_images/pose_kps_00008_.png
#   inflating: /content/pose_images/pose_kps_00009_.png
#   inflating: /content/pose_images/pose_kps_00010_.png
#   inflating: /content/pose_images/pose_kps_00011_.png
#   inflating: /content/pose_images/pose_kps_00012_.png
#   inflating: /content/pose_images/pose_kps_00013_.png
#   inflating: /content/pose_images/pose_kps_00014_.png
#   inflating: /content/pose_images/pose_kps_00015_.png
#   inflating: /content/pose_images/pose_kps_00016_.png
#   inflating: /content/pose_images/pose_kps_00017_.png
#   inflating: /content/pose_images/pose_kps_00018_.png
#   inflating: /content/pose_images/pose_kps_00019_.png
#   inflating: /content/pose_images/pose_kps_00020_.png
#   inflating: /content/pose_images/pose_kps_00021_.png
#   inflating: /content/pose_images/pose_kps_00022_.png
#   inflating: /content/pose_images/pose_kps_00023_.png
#   inflating: /content/pose_images/pose_kps_00024_.png
#   inflating: /content/pose_images/pose_kps_00025_.png
#   inflating: /content/pose_images/pose_kps_00026_.png
#   inflating: /content/pose_images/pose_kps_00027_.png
#   inflating: /content/pose_images/pose_kps_00028_.png
#   inflating: /content/pose_images/pose_kps_00029_.png
#   inflating: /content/pose_images/pose_kps_00030_.png
#   inflating: /content/pose_images/pose_open_pose_00001_.png
#   inflating: /content/pose_images/pose_open_pose_00002_.png
#   inflating: /content/pose_images/pose_open_pose_00003_.png
#   inflating: /content/pose_images/pose_open_pose_00004_.png
#   inflating: /content/pose_images/pose_open_pose_00005_.png
#   inflating: /content/pose_images/pose_open_pose_00006_.png
#   inflating: /content/pose_images/pose_open_pose_00007_.png
#   inflating: /content/pose_images/pose_open_pose_00008_.png
#   inflating: /content/pose_images/pose_open_pose_00009_.png
#   inflating: /content/pose_images/pose_open_pose_00010_.png
#   inflating: /content/pose_images/pose_open_pose_00011_.png
#   inflating: /content/pose_images/pose_open_pose_00012_.png
#   inflating: /content/pose_images/pose_open_pose_00013_.png
#   inflating: /content/pose_images/pose_open_pose_00014_.png
#   inflating: /content/pose_images/pose_open_pose_00015_.png
#   inflating: /content/pose_images/pose_open_pose_00016_.png
#   inflating: /content/pose_images/pose_open_pose_00017_.png
#   inflating: /content/pose_images/pose_open_pose_00018_.png
#   inflating: /content/pose_images/pose_open_pose_00019_.png
#   inflating: /content/pose_images/pose_open_pose_00020_.png
#   inflating: /content/pose_images/pose_open_pose_00021_.png
#   inflating: /content/pose_images/pose_open_pose_00022_.png
#   inflating: /content/pose_images/pose_open_pose_00023_.png
#   inflating: /content/pose_images/pose_open_pose_00024_.png
#   inflating: /content/pose_images/pose_open_pose_00025_.png
#   inflating: /content/pose_images/pose_open_pose_00026_.png
#   inflating: /content/pose_images/pose_open_pose_00027_.png
#   inflating: /content/pose_images/pose_open_pose_00028_.png
#   inflating: /content/pose_images/pose_open_pose_00029_.png
#   inflating: /content/pose_images/pose_open_pose_00030_.png

# %%
# %cd /content/TotoroUI
import sys
sys.path.append('/content/TotoroUI/IPAdapter')
import IPAdapterPlus
sys.path.append('/content/TotoroUI/InstantID')
import InstantID
sys.path.append('/content/TotoroUI/Impact')
import torch
import numpy as np
from PIL import Image
import totoro
import nodes
import detailer
import scipy
import model_management
import gc
import random

with torch.no_grad():
    model_patcher, clip, vae, clipvision = totoro.sd.load_checkpoint_guess_config("/content/TotoroUI/models/dreamshaperXL_lightningDPMSDE.safetensors", output_vae=True, output_clip=True, embedding_directory=None)
    # model_patcher, clip, vae, clipvision = totoro.sd.load_checkpoint_guess_config("/content/TotoroUI/models/raemuXL_v35Lightning.safetensors", output_vae=True, output_clip=True, embedding_directory=None)
    IPAdapterPlus_model = IPAdapterPlus.IPAdapterUnifiedLoader().load_models(model_patcher, 'PLUS FACE (portraits)', lora_strength=0.0, provider="CUDA")
    instantid = InstantID.InstantIDModelLoader().load_model("/content/TotoroUI/models/instantid/ip-adapter.bin")
    insightface = InstantID.InstantIDFaceAnalysis().load_insight_face("CUDA")
    instantid_control_net = totoro.controlnet.load_controlnet("/content/TotoroUI/models/controlnet/SDXL/instantid/diffusion_pytorch_model.safetensors")
    output_image, output_mask = nodes.LoadImage().load_image("/content/anya.jpg")
    image_kps, image_kps_mask = nodes.LoadImage().load_image("/content/pose_images/headshot_kps_00003_.png")
    image_dw, image_dw_mask = nodes.LoadImage().load_image("/content/pose_images/headshot_dw_pose_00003_.png")
    ip_model_patcher = IPAdapterPlus.IPAdapterAdvanced().apply_ipadapter(IPAdapterPlus_model[0], IPAdapterPlus_model[1], image=output_image, weight_type="style transfer")
    tokens = clip.tokenize("a portrait photo of a woman")
    cond, pooled = clip.encode_from_tokens(tokens, return_pooled=True)
    cond = [[cond, {"pooled_output": pooled}]]
    n_tokens = clip.tokenize("(nsfw:1.5), nipple, nude, naked, lowres, child, getty, bad anatomy, bad hands, text, error, missing fingers, extra digit, fewer digits, cropped, worst quality, low quality, normal quality, jpeg artifacts, signature, watermark, username, blurry, artist name, trademark, watermark, title, multiple view, reference sheet, mutated hands and fingers, poorly drawn face, mutation, deformed, ugly, bad proportions, gross proportions, malformed limbs, missing arms, missing legs, extra arms, extra legs, fused fingers, too many fingers, long neck, tatoo, amateur drawing, odd eyes, uneven eyes, unnatural face, uneven nostrils, crooked mouth, bad teeth, crooked teeth, photoshop, video game, censor, censored, ghost, b&w, weird colors, gradient background, spotty background, blurry background, ugly background, simple background, realistic, out of frame, extra objects, gross, ugly, tiling, poorly drawn hands, poorly drawn feet, poorly drawn face, out of focus, blurry, very long body, duplicate, morbid, mutilated, extra fingers, mutated hands, poorly drawn eyes, cloned face, disfigured, deformed, cross-eye, extra limbs, missing limb, malformed hands, mutated, morbid, mutilated, disfigured, extra arms, extra hands, mangled fingers, contorted, conjoined, mismatched limbs, mismatched parts, bad perspective, black and white, oversaturated, undersaturated, bad shadow, cropped image, draft, grainy, pixelated")
    n_cond, n_pooled = clip.encode_from_tokens(n_tokens, return_pooled=True)
    n_cond = [[n_cond, {"pooled_output": n_pooled}]]
    work_model, instantid_cond, instantid_n_cond = InstantID.ApplyInstantID().apply_instantid(instantid=instantid[0], insightface=insightface[0], control_net=instantid_control_net, image=output_image, model=ip_model_patcher[0], positive=cond, negative=n_cond, start_at=0.0, end_at=1.0, weight=0.80, image_kps=image_kps)
    openpose_control_net = totoro.controlnet.load_controlnet("/content/TotoroUI/models/controlnet/thibaud_xl_openpose.safetensors")
    openpose_cond = nodes.ControlNetApply().apply_controlnet(conditioning=instantid_cond, control_net=openpose_control_net, image=image_dw, strength=0.90)
# Out:
# /content/TotoroUI
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_233/1149105420.py in <cell line: 0>()
#       4 import IPAdapterPlus
#       5 sys.path.append('/content/TotoroUI/InstantID')
# ----> 6 import InstantID
#       7 sys.path.append('/content/TotoroUI/Impact')
#       8 import torch
#
# /content/TotoroUI/InstantID/InstantID.py in <module>
#      11 from InstantID_utils import tensor_to_image
#      12
# ---> 13 from insightface.app import FaceAnalysis
#      14
#      15 try:
#
# ModuleNotFoundError: No module named 'insightface'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
instantid = None
insightface = None
instantid_control_net = None
ip_model_patcher = None
cond = None
n_cond = None
model_patcher = None
clip = None
clipvision = None
IPAdapterPlus_model = None
model_management.cleanup_models()
gc.collect()
model_management.soft_empty_cache()

ran = random.randint(0, 65535)
# ran = 10
print(ran)

with torch.inference_mode():
    latent = {"samples":torch.zeros([1, 4, 1024 // 8, 1024 // 8])}
    sample = nodes.common_ksampler(model=work_model,
                          seed=ran,
                          steps=4,
                          cfg=1.3,
                          sampler_name="dpmpp_sde_gpu",
                          scheduler="karras",
                          positive=openpose_cond[0],
                          negative=instantid_n_cond,
                          latent=latent,
                          denoise=0.95)

    sample = sample[0]["samples"].to(torch.float16)
    vae.first_stage_model.cuda()
    decoded = vae.decode(sample).detach()

Image.fromarray(np.array(decoded*255, dtype=np.uint8)[0]).save("/content/output_image.png")

# %%
exit()  # If T4

# %%
# %cd /content/TotoroUI
import sys
sys.path.append('/content/TotoroUI/IPAdapter')
import IPAdapterPlus
sys.path.append('/content/TotoroUI/InstantID')
import InstantID
sys.path.append('/content/TotoroUI/Impact')
import torch
import numpy as np
from PIL import Image
import totoro
import nodes
import detailer
import scipy
import model_management
import gc
import random

ran = random.randint(0, 65535)
# ran = 10
print(ran)

with torch.inference_mode():
    decoded = Image.open("/content/output_image.png")
    decoded = detailer.pil2tensor(decoded)

    model_patcher, clip, vae, clipvision = totoro.sd.load_checkpoint_guess_config("/content/TotoroUI/models/dreamshaperXL_lightningDPMSDE.safetensors", output_vae=True, output_clip=True, embedding_directory=None)

    model = detailer.load_yolo("/content/TotoroUI/models/ultralytics/bbox/Eyes.pt")
    bbox_detector = detailer.UltraBBoxDetector(model)

    bbox_detector.setAux('face')
    segs = bbox_detector.detect(image=decoded, threshold=0.50, dilation=10, crop_factor=3.0, drop_size=10, detailer_hook=None)
    bbox_detector.setAux(None)

    face_tokens = clip.tokenize("perfect eyes")
    face_cond, face_pooled = clip.encode_from_tokens(face_tokens, return_pooled=True)
    face_cond = [[face_cond, {"pooled_output": face_pooled}]]
    face_n_tokens = clip.tokenize("deformed pupils, deformed eyes, ugly eyes")
    face_n_cond, face_n_pooled = clip.encode_from_tokens(face_n_tokens, return_pooled=True)
    face_n_cond = [[face_n_cond, {"pooled_output": face_n_pooled}]]

    enhanced_img, _, cropped_enhanced, cropped_enhanced_alpha, cnet_pil_list, new_segs = \
        detailer.DetailerForEach.do_detail(image=decoded, segs=segs, model=model_patcher, clip=clip, vae=vae, guide_size=384, guide_size_for_bbox=True, max_size=1024, seed=ran, steps=4, cfg=1.0,
                                    sampler_name="dpmpp_sde", scheduler="karras", positive=face_cond, negative=face_n_cond, denoise=0.35, feather=5, noise_mask=True,
                                    force_inpaint=True, wildcard_opt=None, detailer_hook=None, refiner_ratio=0.2, refiner_model=None, refiner_clip=None, refiner_positive=None, refiner_negative=None,
                                    cycle=1, inpaint_model=False, noise_mask_feather=20)
    upscaled_img = nodes.ImageScaleBy.upscale(_, image=enhanced_img, upscale_method="lanczos", scale_by=1.50)
    adjust_img = detailer.image_filters(image=upscaled_img[0], brightness=0.0, contrast=1.0, saturation=1.0, sharpness=4, blur=0, gaussian_blur=0.0, edge_enhance=0.10, detail_enhance=True)

Image.fromarray(np.array(adjust_img[0]*255, dtype=np.uint8)[0])

# %%
model_management.cleanup_models()
gc.collect()
model_management.soft_empty_cache()

with torch.inference_mode():
    latent = { "samples": vae.encode(adjust_img[0]) }
    sample = nodes.common_ksampler(model=work_model,
                        seed=ran,
                        steps=4,
                        cfg=1.3,
                        sampler_name="dpmpp_sde_gpu",
                        scheduler="karras",
                        positive=instantid_cond,
                        negative=instantid_n_cond,
                        latent=latent,
                        denoise=0.20)

    sample = sample[0]["samples"].to(torch.float16)

    vae.first_stage_model.cuda()
    decoded = vae.decode(sample).detach()
    enhanced_img, _, cropped_enhanced, cropped_enhanced_alpha, cnet_pil_list, new_segs = \
    detailer.DetailerForEach.do_detail(image=decoded, segs=segs, model=model_patcher, clip=clip, vae=vae, guide_size=384, guide_size_for_bbox=True, max_size=1024, seed=ran, steps=4, cfg=1.0,
                                sampler_name="dpmpp_sde", scheduler="karras", positive=face_cond, negative=face_n_cond, denoise=0.35, feather=5, noise_mask=True,
                                force_inpaint=True, wildcard_opt=None, detailer_hook=None, refiner_ratio=0.2, refiner_model=None, refiner_clip=None, refiner_positive=None, refiner_negative=None,
                                cycle=1, inpaint_model=False, noise_mask_feather=20)
    upscaled_img = nodes.ImageScaleBy.upscale(_, image=enhanced_img, upscale_method="lanczos", scale_by=1.50)
    adjust_img = detailer.image_filters(image=upscaled_img[0], brightness=0.0, contrast=1.0, saturation=1.0, sharpness=4, blur=0, gaussian_blur=0.0, edge_enhance=0.10, detail_enhance=True)
Image.fromarray(np.array(adjust_img[0]*255, dtype=np.uint8)[0])
